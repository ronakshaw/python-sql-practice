# %% [markdown]
# # Variables in python

# %%
x = 5
print(x)
# Out:
# 5

# %%
print (type(x))
# Out:
# <class 'str'>

# %%
x = 'chocolate'
print(x)
# Out:
# chocolate

# %%
y = 'student'
y = 'Ronak'
Y = 'loves chocolate' # variables are case sensitive
print(y,Y)
# Out:
# Ronak loves chocolate

# %%
z = "i'm good in math"
print(z)
# Out:
# i'm good in math

# %%
analysis_report = """    Total revenue is ₹1M.
    Best performing region is north.
    Highest performing section is electronics.
"""
print(analysis_report)
# Out:
#     Total revenue is ₹1M.
#     Best performing region is north.
#     Highest performing section is electronics.

# %%
# camel case
testVariableCase = 'vanilla'

# %%
#pascal case
TestVariableCase = 'vanilla'

# %%
# snake case
test_variable_case = 'vanilla'
# best to use

# %%
# variable naming used
variable_name = 2
variableName = 2
VariableName = 2
_variablename = 2

# %%
#variable naming not used
Variablename = 2
variable name = 2
5variablename = 2

# %%
x =2 
y=3
z = 4
print(x+y+z)
# Out:
# 9

# %%
x = 'vanilla'
y = 2
# print(x+y) will not work insteal
print(y,x)
# Out:
# 2 vanilla

# %%
x,y,z = 'vanilla', 'chocolate', 'strawberry'
print(x,y,z)
# Out:
# vanilla chocolate strawberry

# %%
x,y,z = 'vanilla', 'chocolate', 'strawberry'
print(x)
print(y)
print(z)
# Out:
# vanilla
# chocolate
# strawberry

# %%
ice_cream = ['vanilla', 'chocolate', 'strawberry']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# vanilla
# chocolate
# strawberry
