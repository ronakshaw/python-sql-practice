# %% [markdown]
# # BMI Calculator

# %%
# BMI = weight (kg) / height (m) ** 2

# %%
Below 18.5 Underweight
18.5 — 24.9 Normal weight ✅
25.0 — 29.9 Overweight
30.0 — 34.9 Obese (Class 1)
35.0 — 39.9 Obese (Class 2)
40 and aboveExtremely Obese (Class 3)

# %%
Name = input("Enter your name: ")
Weight = float(input("Enter your weight(kg): "))
Height =float(input("Enter your height(m): "))
BMI = Weight / Height ** 2

print(BMI)

if BMI < 18.5:
    print(Name + " you are Underweight")
elif BMI <24.9:
    print(Name + " you are Normal weight")
elif BMI <29.9:
    print(Name + " you are Overweight")
elif BMI <34.9:
    print(Name + " you are Obese (Class 1)")
elif BMI <39.9:
    print(Name + " you are Obese (Class 2)")
else:
    print(Name + " you are above Extremely Obese (Class 3)")
# Out:
# Enter your name:  anup
# Enter your weight(kg):  75
