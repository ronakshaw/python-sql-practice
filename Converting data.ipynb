# %% [markdown]
# # convering data

# %%
int_value = 5
str_value = '7'
str_conv = int(str_value)

# %%
print(int_value + str_conv)
# Out:
# 12

# %%
int_conv = str(int_value)

# %%
type(int_conv)
# Out:
# str

# %%
list_type = [1,2,3]
type(tuple(list_type))
# Out:
# tuple

# %%
tuple_ = (1,2,3,3,2,1)
list(tuple_)
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
list_type = [1,2,3,5,3,2,1]
set(list_type)
# Out:
# {1, 2, 3, 5}

# %%
dict_type={'name':'ronak','age':23}

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
list(dict_type.keys())
# Out:
# ['name', 'age']

# %%
long_str = "I like to party"
set(long_str)
# Out:
# {' ', 'I', 'a', 'e', 'i', 'k', 'l', 'o', 'p', 'r', 't', 'y'}
